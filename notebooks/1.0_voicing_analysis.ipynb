# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from pathlib import Path

import torchaudio
import numpy as np
import pandas as pd
from IPython.display import display, Audio
from tqdm.auto import tqdm
import opensmile

sys.path.append("..")
from cybb_mist.speech_analysis import analyze_utterance
# Out:
# torchvision is not available - cannot save figures

# %%
user = "jonas"

if user.lower() == "jonas":
    BASE_PATH = Path("/media/uz_study/EEGstudy2_idlab_cloud")
elif user.lower() == "mitchel":
    #     BASE_PATH = Path("Z:/shares/ghep_lab/2021_VanhollebekeKappen_EEGStudy2_MIST_Cyberball_Audio/")
    BASE_PATH = Path("D:/Data/EEG_Study_2")
DATA_PATH = BASE_PATH.joinpath("Data/Raw/Audio")

wavs = list(DATA_PATH.glob('**/*.wav'))
print(len(wavs))
# Out:
# 623

# %% [markdown]
# ## Creating images

# %%
img_save_dir = DATA_PATH.parent.parent / 'interim' / 'audio_images'
os.makedirs(img_save_dir, exist_ok=True)

opensmile.Smile(
        feature_set=opensmile.FeatureSet.GeMAPSv01b,
        feature_level=opensmile.FeatureLevel.LowLevelDescriptors,
).feature_names
# Out:
# ['Loudness_sma3',
#  'alphaRatio_sma3',
#  'hammarbergIndex_sma3',
#  'slope0-500_sma3',
#  'slope500-1500_sma3',
#  'F0semitoneFrom27.5Hz_sma3nz',
#  'jitterLocal_sma3nz',
#  'shimmerLocaldB_sma3nz',
#  'HNRdBACF_sma3nz',
#  'logRelF0-H1-H2_sma3nz',
#  'logRelF0-H1-A3_sma3nz',
#  'F1frequency_sma3nz',
#  'F1bandwidth_sma3nz',
#  'F1amplitudeLogRelF0_sma3nz',
#  'F2frequency_sma3nz',
#  'F2amplitudeLogRelF0_sma3nz',
#  'F3frequency_sma3nz',
#  'F3amplitudeLogRelF0_sma3nz']

# %%
for wav_path in tqdm(wavs):
    ppt_id, task = wav_path.parent.name.split("_")[1:3]
    desc_type, exp_phase = wav_path.stem.split("_")[1:3]

    save_path = img_save_dir / str(ppt_id)
    os.makedirs(save_path, exist_ok=True)
    try:
        analyze_utterance(
            wav_path,
            feat_cols=[
                "F0semitoneFrom27.5Hz_sma3nz",
                "jitterLocal_sma3nz",
                "shimmerLocaldB_sma3nz,
                "HNRdBACF_sma3nz",
            ],
            vad=True,
            audio=False,
            plot_type="return",
        ).write_image(
            save_path / ("_".join([task, desc_type, exp_phase]) + ".png"),
            width=2*2000,
            height=2*1200,
        )
    except AssertionError:
        continue

    # break
# Out:
#   0%|          | 0/623 [00:00<?, ?it/s]
# arr_orig_wav_n size [1, 2870000] orig fs 44100
# arr_orig_wav_n size [1, 2830000] orig fs 44100
# arr_orig_wav_n size [1, 2785000] orig fs 44100
# arr_orig_wav_n size [1, 2930000] orig fs 44100
# arr_orig_wav_n size [1, 2825000] orig fs 44100
# arr_orig_wav_n size [1, 2725000] orig fs 44100
# arr_orig_wav_n size [1, 2735000] orig fs 44100
# arr_orig_wav_n size [1, 2730000] orig fs 44100
# arr_orig_wav_n size [1, 2895000] orig fs 44100
# arr_orig_wav_n size [1, 2910000] orig fs 44100
# arr_orig_wav_n size [1, 2905000] orig fs 44100
# arr_orig_wav_n size [1, 2670000] orig fs 44100
# arr_orig_wav_n size [1, 2990000] orig fs 44100
# arr_orig_wav_n size [1, 3385000] orig fs 44100
# arr_orig_wav_n size [1, 3160000] orig fs 44100
# arr_orig_wav_n size [1, 2740000] orig fs 44100
# arr_orig_wav_n size [1, 2850000] orig fs 44100
# arr_orig_wav_n size [1, 2765000] orig fs 44100
# arr_orig_wav_n size [1, 2830000] orig fs 44100
# arr_orig_wav_n size [1, 2940000] orig fs 44100
# arr_orig_wav_n size [1, 3385000] orig fs 44100
# arr_orig_wav_n size [1, 3170000] orig fs 44100
# arr_orig_wav_n size [1, 3020000] orig fs 44100
# arr_orig_wav_n size [1, 3445000] orig fs 44100
# arr_orig_wav_n size [1, 3245000] orig fs 44100
# arr_orig_wav_n size [1, 3500000] orig fs 44100
# arr_orig_wav_n size [1, 4390000] orig fs 44100
# arr_orig_wav_n size [1, 3320000] orig fs 44100
# arr_orig_wav_n size [1, 3120000] orig fs 44100
# arr_orig_wav_n size [1, 3740000] orig fs 44100
# arr_orig_wav_n size [1, 2775000] orig fs 44100
# arr_orig_wav_n size [1, 2790000] orig fs 44100
# arr_orig_wav_n size [1, 2725000] orig fs 44100
# arr_orig_wav_n size [1, 3050000] orig fs 44100
# arr_orig_wav_n size [1, 2950000] orig fs 44100
# arr_orig_wav_n size [1, 2720000] orig fs 44100
# arr_orig_wav_n size [1, 2775000] orig fs 44100
# arr_orig_wav_n size [1, 2980000] orig fs 44100
# arr_orig_wav_n size [1, 3160000] orig fs 44100
# arr_orig_wav_n size [1, 3000000] orig fs 44100
# arr_orig_wav_n size [1, 2810000] orig fs 44100
# arr_orig_wav_n size [1, 3325000] orig fs 44100
# arr_orig_wav_n size [1, 3085000] orig fs 44100
# arr_orig_wav_n size [1, 3635000] orig fs 44100
# arr_orig_wav_n size [1, 3305000] orig fs 44100
# arr_orig_wav_n size [1, 2825000] orig fs 44100
# arr_orig_wav_n size [1, 3210000] orig fs 44100
# arr_orig_wav_n size [1, 2830000] orig fs 44100
# arr_orig_wav_n size [1, 2985000] orig fs 44100
# arr_orig_wav_n size [1, 3025000] orig fs 44100
# arr_orig_wav_n size [1, 2735000] orig fs 44100
# arr_orig_wav_n size [1, 2670000] orig fs 44100
# arr_orig_wav_n size [1, 2670000] orig fs 44100
# arr_orig_wav_n size [1, 2990000] orig fs 44100
# arr_orig_wav_n size [1, 2700000] orig fs 44100
# arr_orig_wav_n size [1, 2700000] orig fs 44100
# arr_orig_wav_n size [1, 2700000] orig fs 44100
# arr_orig_wav_n size [1, 2705000] orig fs 44100
# arr_orig_wav_n size [1, 2830000] orig fs 44100
# arr_orig_wav_n size [1, 2850000] orig fs 44100
# arr_orig_wav_n size [1, 3705000] orig fs 44100
# arr_orig_wav_n size [1, 2965000] orig fs 44100
# arr_orig_wav_n size [1, 3310000] orig fs 44100
# arr_orig_wav_n size [1, 3305000] orig fs 44100
# arr_orig_wav_n size [1, 2870000] orig fs 44100
# arr_orig_wav_n size [1, 3060000] orig fs 44100
# arr_orig_wav_n size [1, 2890000] orig fs 44100
# arr_orig_wav_n size [1, 2945000] orig fs 44100
# arr_orig_wav_n size [1, 3640000] orig fs 44100
# arr_orig_wav_n size [1, 3355000] orig fs 44100
# arr_orig_wav_n size [1, 2670000] orig fs 44100
# arr_orig_wav_n size [1, 3565000] orig fs 44100
# arr_orig_wav_n size [1, 2740000] orig fs 44100
# arr_orig_wav_n size [1, 3675000] orig fs 44100
# arr_orig_wav_n size [1, 3120000] orig fs 44100
# arr_orig_wav_n size [1, 3285000] orig fs 44100
# arr_orig_wav_n size [1, 2810000] orig fs 44100
# arr_orig_wav_n size [1, 3430000] orig fs 44100
# arr_orig_wav_n size [1, 2810000] orig fs 44100
# arr_orig_wav_n size [1, 3165000] orig fs 44100
# arr_orig_wav_n size [1, 2780000] orig fs 44100
# arr_orig_wav_n size [1, 2775000] orig fs 44100
# arr_orig_wav_n size [1, 2760000] orig fs 44100
# arr_orig_wav_n size [1, 2895000] orig fs 44100
# arr_orig_wav_n size [1, 3005000] orig fs 44100
# arr_orig_wav_n size [1, 2860000] orig fs 44100
# arr_orig_wav_n size [1, 3005000] orig fs 44100
# arr_orig_wav_n size [1, 3140000] orig fs 44100
# arr_orig_wav_n size [1, 2865000] orig fs 44100
# arr_orig_wav_n size [1, 2920000] orig fs 44100
# arr_orig_wav_n size [1, 2740000] orig fs 44100
# arr_orig_wav_n size [1, 2725000] orig fs 44100
# arr_orig_wav_n size [1, 3035000] orig fs 44100
# arr_orig_wav_n size [1, 2825000] orig fs 44100
# arr_orig_wav_n size [1, 2785000] orig fs 44100
# arr_orig_wav_n size [1, 2815000] orig fs 44100
# arr_orig_wav_n size [1, 2930000] orig fs 44100
# arr_orig_wav_n size [1, 2970000] orig fs 44100
# arr_orig_wav_n size [1, 2790000] orig fs 44100
# arr_orig_wav_n size [1, 3055000] orig fs 44100
# arr_orig_wav_n size [1, 2745000] orig fs 44100
# arr_orig_wav_n size [1, 2720000] orig fs 44100
# arr_orig_wav_n size [1, 2735000] orig fs 44100
# arr_orig_wav_n size [1, 3025000] orig fs 44100
# arr_orig_wav_n size [1, 3140000] orig fs 44100
# arr_orig_wav_n size [1, 4175000] orig fs 44100
# arr_orig_wav_n size [1, 4445000] orig fs 44100
# arr_orig_wav_n size [1, 3150000] orig fs 44100
# arr_orig_wav_n size [1, 3905000] orig fs 44100
# arr_orig_wav_n size [1, 3120000] orig fs 44100
# arr_orig_wav_n size [1, 3070000] orig fs 44100
# arr_orig_wav_n size [1, 2980000] orig fs 44100
# arr_orig_wav_n size [1, 3075000] orig fs 44100
# arr_orig_wav_n size [1, 3095000] orig fs 44100
# arr_orig_wav_n size [1, 4225000] orig fs 44100
# arr_orig_wav_n size [1, 2770000] orig fs 44100
# arr_orig_wav_n size [1, 2725000] orig fs 44100
# arr_orig_wav_n size [1, 2780000] orig fs 44100
# arr_orig_wav_n size [1, 3325000] orig fs 44100
# arr_orig_wav_n size [1, 2945000] orig fs 44100
# arr_orig_wav_n size [1, 2735000] orig fs 44100
# arr_orig_wav_n size [1, 2730000] orig fs 44100
# arr_orig_wav_n size [1, 2735000] orig fs 44100
# arr_orig_wav_n size [1, 2835000] orig fs 44100
# arr_orig_wav_n size [1, 2900000] orig fs 44100
# arr_orig_wav_n size [1, 2770000] orig fs 44100
# arr_orig_wav_n size [1, 3005000] orig fs 44100
# arr_orig_wav_n size [1, 2835000] orig fs 44100
# arr_orig_wav_n size [1, 3035000] orig fs 44100
# arr_orig_wav_n size [1, 2955000] orig fs 44100
# arr_orig_wav_n size [1, 2750000] orig fs 44100
# arr_orig_wav_n size [1, 2885000] orig fs 44100
# arr_orig_wav_n size [1, 2935000] orig fs 44100
# arr_orig_wav_n size [1, 2935000] orig fs 44100
# arr_orig_wav_n size [1, 3565000] orig fs 44100
# arr_orig_wav_n size [1, 2740000] orig fs 44100
# arr_orig_wav_n size [1, 4355000] orig fs 44100
# arr_orig_wav_n size [1, 2875000] orig fs 44100
# arr_orig_wav_n size [1, 3370000] orig fs 44100
# arr_orig_wav_n size [1, 2890000] orig fs 44100
# arr_orig_wav_n size [1, 3155000] orig fs 44100
# arr_orig_wav_n size [1, 2865000] orig fs 44100
# arr_orig_wav_n size [1, 3770000] orig fs 44100
# arr_orig_wav_n size [1, 2945000] orig fs 44100
# arr_orig_wav_n size [1, 2870000] orig fs 44100
# arr_orig_wav_n size [1, 2775000] orig fs 44100
# arr_orig_wav_n size [1, 2780000] orig fs 44100
# arr_orig_wav_n size [1, 2855000] orig fs 44100
# arr_orig_wav_n size [1, 2940000] orig fs 44100
# arr_orig_wav_n size [1, 2865000] orig fs 44100
# arr_orig_wav_n size [1, 2780000] orig fs 44100
# arr_orig_wav_n size [1, 2860000] orig fs 44100
# arr_orig_wav_n size [1, 2800000] orig fs 44100
# arr_orig_wav_n size [1, 2765000] orig fs 44100
# arr_orig_wav_n size [1, 3070000] orig fs 44100
# arr_orig_wav_n size [1, 2730000] orig fs 44100
# arr_orig_wav_n size [1, 4280000] orig fs 44100
# arr_orig_wav_n size [1, 2725000] orig fs 44100
# arr_orig_wav_n size [1, 3060000] orig fs 44100
# arr_orig_wav_n size [1, 3075000] orig fs 44100
# arr_orig_wav_n size [1, 2935000] orig fs 44100
# arr_orig_wav_n size [1, 2810000] orig fs 44100
# arr_orig_wav_n size [1, 2990000] orig fs 44100
# arr_orig_wav_n size [1, 3015000] orig fs 44100
# arr_orig_wav_n size [1, 2990000] orig fs 44100
# arr_orig_wav_n size [1, 2780000] orig fs 44100
# arr_orig_wav_n size [1, 2780000] orig fs 44100
# arr_orig_wav_n size [1, 2765000] orig fs 44100
# arr_orig_wav_n size [1, 2910000] orig fs 44100
# arr_orig_wav_n size [1, 2970000] orig fs 44100
# arr_orig_wav_n size [1, 2825000] orig fs 44100
# arr_orig_wav_n size [1, 3210000] orig fs 44100
# arr_orig_wav_n size [1, 2760000] orig fs 44100
# arr_orig_wav_n size [1, 2715000] orig fs 44100
# arr_orig_wav_n size [1, 2760000] orig fs 44100
# arr_orig_wav_n size [1, 3155000] orig fs 44100
# arr_orig_wav_n size [1, 2915000] orig fs 44100
# arr_orig_wav_n size [1, 2770000] orig fs 44100
# arr_orig_wav_n size [1, 2890000] orig fs 44100
# arr_orig_wav_n size [1, 2840000] orig fs 44100
# arr_orig_wav_n size [1, 2895000] orig fs 44100
# arr_orig_wav_n size [1, 2915000] orig fs 44100
# arr_orig_wav_n size [1, 2960000] orig fs 44100
# arr_orig_wav_n size [1, 2930000] orig fs 44100
# arr_orig_wav_n size [1, 2880000] orig fs 44100
# arr_orig_wav_n size [1, 2735000] orig fs 44100
# arr_orig_wav_n size [1, 2740000] orig fs 44100
# arr_orig_wav_n size [1, 2710000] orig fs 44100
# arr_orig_wav_n size [1, 3100000] orig fs 44100
# arr_orig_wav_n size [1, 2945000] orig fs 44100
# arr_orig_wav_n size [1, 2810000] orig fs 44100
# arr_orig_wav_n size [1, 2775000] orig fs 44100
# arr_orig_wav_n size [1, 2800000] orig fs 44100
# arr_orig_wav_n size [1, 2750000] orig fs 44100
# arr_orig_wav_n size [1, 2870000] orig fs 44100
# arr_orig_wav_n size [1, 2780000] orig fs 44100
# arr_orig_wav_n size [1, 2745000] orig fs 44100
# arr_orig_wav_n size [1, 2815000] orig fs 44100
# arr_orig_wav_n size [1, 3090000] orig fs 44100
# arr_orig_wav_n size [1, 2845000] orig fs 44100
# arr_orig_wav_n size [1, 2775000] orig fs 44100
# arr_orig_wav_n size [1, 2975000] orig fs 44100
# arr_orig_wav_n size [1, 2795000] orig fs 44100
# arr_orig_wav_n size [1, 2900000] orig fs 44100
# arr_orig_wav_n size [1, 2835000] orig fs 44100
# arr_orig_wav_n size [1, 2775000] orig fs 44100
# arr_orig_wav_n size [1, 2820000] orig fs 44100
# arr_orig_wav_n size [1, 2810000] orig fs 44100
# arr_orig_wav_n size [1, 3160000] orig fs 44100
# arr_orig_wav_n size [1, 2995000] orig fs 44100
# arr_orig_wav_n size [1, 2760000] orig fs 44100
# arr_orig_wav_n size [1, 2800000] orig fs 44100
# arr_orig_wav_n size [1, 2755000] orig fs 44100
# arr_orig_wav_n size [1, 2960000] orig fs 44100
# arr_orig_wav_n size [1, 2975000] orig fs 44100
# arr_orig_wav_n size [1, 2865000] orig fs 44100
# arr_orig_wav_n size [1, 2750000] orig fs 44100
# arr_orig_wav_n size [1, 2955000] orig fs 44100
# arr_orig_wav_n size [1, 3350000] orig fs 44100
# arr_orig_wav_n size [1, 2795000] orig fs 44100
# arr_orig_wav_n size [1, 3065000] orig fs 44100
# arr_orig_wav_n size [1, 2795000] orig fs 44100
# arr_orig_wav_n size [1, 2885000] orig fs 44100
# arr_orig_wav_n size [1, 2940000] orig fs 44100
# arr_orig_wav_n size [1, 3125000] orig fs 44100
# arr_orig_wav_n size [1, 3650000] orig fs 44100
# arr_orig_wav_n size [1, 2755000] orig fs 44100
# arr_orig_wav_n size [1, 2760000] orig fs 44100
# arr_orig_wav_n size [1, 3440000] orig fs 44100
# arr_orig_wav_n size [1, 2955000] orig fs 44100
# arr_orig_wav_n size [1, 2740000] orig fs 44100
# arr_orig_wav_n size [1, 2825000] orig fs 44100
# arr_orig_wav_n size [1, 2780000] orig fs 44100
# arr_orig_wav_n size [1, 3345000] orig fs 44100
# arr_orig_wav_n size [1, 3155000] orig fs 44100
# arr_orig_wav_n size [1, 2980000] orig fs 44100
# arr_orig_wav_n size [1, 2885000] orig fs 44100
# arr_orig_wav_n size [1, 2820000] orig fs 44100
# arr_orig_wav_n size [1, 3070000] orig fs 44100
# arr_orig_wav_n size [1, 3125000] orig fs 44100
# arr_orig_wav_n size [1, 2775000] orig fs 44100
# arr_orig_wav_n size [1, 2800000] orig fs 44100
# arr_orig_wav_n size [1, 2725000] orig fs 44100
# arr_orig_wav_n size [1, 3045000] orig fs 44100
# arr_orig_wav_n size [1, 2995000] orig fs 44100
# arr_orig_wav_n size [1, 3075000] orig fs 44100
# arr_orig_wav_n size [1, 2780000] orig fs 44100
# arr_orig_wav_n size [1, 2775000] orig fs 44100
# arr_orig_wav_n size [1, 3315000] orig fs 44100
# arr_orig_wav_n size [1, 3170000] orig fs 44100
# arr_orig_wav_n size [1, 3090000] orig fs 44100
# arr_orig_wav_n size [1, 3190000] orig fs 44100
# arr_orig_wav_n size [1, 3210000] orig fs 44100
# arr_orig_wav_n size [1, 3115000] orig fs 44100
# arr_orig_wav_n size [1, 2875000] orig fs 44100
# arr_orig_wav_n size [1, 3205000] orig fs 44100
# arr_orig_wav_n size [1, 2735000] orig fs 44100
# arr_orig_wav_n size [1, 2740000] orig fs 44100
# arr_orig_wav_n size [1, 2840000] orig fs 44100
# arr_orig_wav_n size [1, 2840000] orig fs 44100
# arr_orig_wav_n size [1, 2950000] orig fs 44100
# arr_orig_wav_n size [1, 3055000] orig fs 44100
# arr_orig_wav_n size [1, 3040000] orig fs 44100
# arr_orig_wav_n size [1, 2905000] orig fs 44100
# arr_orig_wav_n size [1, 3065000] orig fs 44100
# arr_orig_wav_n size [1, 2720000] orig fs 44100
# arr_orig_wav_n size [1, 2970000] orig fs 44100
# arr_orig_wav_n size [1, 2850000] orig fs 44100
# arr_orig_wav_n size [1, 2690000] orig fs 44100
# arr_orig_wav_n size [1, 2945000] orig fs 44100
# arr_orig_wav_n size [1, 2950000] orig fs 44100
# arr_orig_wav_n size [1, 2770000] orig fs 44100
# arr_orig_wav_n size [1, 2705000] orig fs 44100
# arr_orig_wav_n size [1, 2765000] orig fs 44100
# arr_orig_wav_n size [1, 2765000] orig fs 44100
# arr_orig_wav_n size [1, 3075000] orig fs 44100
# arr_orig_wav_n size [1, 3030000] orig fs 44100
# arr_orig_wav_n size [1, 3030000] orig fs 44100
# arr_orig_wav_n size [1, 3380000] orig fs 44100
# arr_orig_wav_n size [1, 3190000] orig fs 44100
# arr_orig_wav_n size [1, 2950000] orig fs 44100
# arr_orig_wav_n size [1, 3085000] orig fs 44100
# arr_orig_wav_n size [1, 3135000] orig fs 44100
# arr_orig_wav_n size [1, 2990000] orig fs 44100
# arr_orig_wav_n size [1, 2980000] orig fs 44100
# arr_orig_wav_n size [1, 3045000] orig fs 44100
# arr_orig_wav_n size [1, 3075000] orig fs 44100
# arr_orig_wav_n size [1, 3095000] orig fs 44100
# arr_orig_wav_n size [1, 3015000] orig fs 44100
# arr_orig_wav_n size [1, 3005000] orig fs 44100
# arr_orig_wav_n size [1, 2895000] orig fs 44100
# arr_orig_wav_n size [1, 3570000] orig fs 44100
# arr_orig_wav_n size [1, 2890000] orig fs 44100
# arr_orig_wav_n size [1, 3485000] orig fs 44100
# arr_orig_wav_n size [1, 3960000] orig fs 44100
# arr_orig_wav_n size [1, 2995000] orig fs 44100
# arr_orig_wav_n size [1, 2980000] orig fs 44100
# arr_orig_wav_n size [1, 3145000] orig fs 44100
# arr_orig_wav_n size [1, 2860000] orig fs 44100
# arr_orig_wav_n size [1, 4370000] orig fs 44100
# arr_orig_wav_n size [1, 2730000] orig fs 44100
# arr_orig_wav_n size [1, 3435000] orig fs 44100
# arr_orig_wav_n size [1, 2970000] orig fs 44100
# arr_orig_wav_n size [1, 2925000] orig fs 44100
# arr_orig_wav_n size [1, 3250000] orig fs 44100
# arr_orig_wav_n size [1, 2760000] orig fs 44100
# arr_orig_wav_n size [1, 2965000] orig fs 44100
# arr_orig_wav_n size [1, 3020000] orig fs 44100
# arr_orig_wav_n size [1, 2805000] orig fs 44100
# arr_orig_wav_n size [1, 3680000] orig fs 44100
# arr_orig_wav_n size [1, 2835000] orig fs 44100
# arr_orig_wav_n size [1, 2900000] orig fs 44100
# arr_orig_wav_n size [1, 3230000] orig fs 44100
# arr_orig_wav_n size [1, 3630000] orig fs 44100
# arr_orig_wav_n size [1, 3175000] orig fs 44100
# arr_orig_wav_n size [1, 2860000] orig fs 44100
# arr_orig_wav_n size [1, 3555000] orig fs 44100
# arr_orig_wav_n size [1, 3235000] orig fs 44100
# arr_orig_wav_n size [1, 3360000] orig fs 44100
# arr_orig_wav_n size [1, 3500000] orig fs 44100
# arr_orig_wav_n size [1, 3085000] orig fs 44100
# arr_orig_wav_n size [1, 2745000] orig fs 44100
# arr_orig_wav_n size [1, 2750000] orig fs 44100
# arr_orig_wav_n size [1, 3455000] orig fs 44100
# arr_orig_wav_n size [1, 3080000] orig fs 44100
# arr_orig_wav_n size [1, 2725000] orig fs 44100
# arr_orig_wav_n size [1, 2875000] orig fs 44100
# arr_orig_wav_n size [1, 3610000] orig fs 44100
# arr_orig_wav_n size [1, 2820000] orig fs 44100
# arr_orig_wav_n size [1, 3075000] orig fs 44100
# arr_orig_wav_n size [1, 2980000] orig fs 44100
# arr_orig_wav_n size [1, 2745000] orig fs 44100
# arr_orig_wav_n size [1, 2915000] orig fs 44100
# arr_orig_wav_n size [1, 3190000] orig fs 44100
# arr_orig_wav_n size [1, 2815000] orig fs 44100
# arr_orig_wav_n size [1, 2825000] orig fs 44100
# arr_orig_wav_n size [1, 2765000] orig fs 44100
# arr_orig_wav_n size [1, 2740000] orig fs 44100
# arr_orig_wav_n size [1, 2760000] orig fs 44100
# arr_orig_wav_n size [1, 2825000] orig fs 44100
# arr_orig_wav_n size [1, 2770000] orig fs 44100
# arr_orig_wav_n size [1, 2995000] orig fs 44100
# arr_orig_wav_n size [1, 3225000] orig fs 44100
# arr_orig_wav_n size [1, 3070000] orig fs 44100
# arr_orig_wav_n size [1, 3155000] orig fs 44100
# arr_orig_wav_n size [1, 3075000] orig fs 44100
# arr_orig_wav_n size [1, 3335000] orig fs 44100
# arr_orig_wav_n size [1, 2985000] orig fs 44100
# arr_orig_wav_n size [1, 3145000] orig fs 44100
# arr_orig_wav_n size [1, 3480000] orig fs 44100
# arr_orig_wav_n size [1, 2900000] orig fs 44100
# arr_orig_wav_n size [1, 2790000] orig fs 44100
# arr_orig_wav_n size [1, 2735000] orig fs 44100
# arr_orig_wav_n size [1, 2870000] orig fs 44100
# arr_orig_wav_n size [1, 2935000] orig fs 44100
# arr_orig_wav_n size [1, 3330000] orig fs 44100
# arr_orig_wav_n size [1, 3235000] orig fs 44100
# arr_orig_wav_n size [1, 3425000] orig fs 44100
# arr_orig_wav_n size [1, 2855000] orig fs 44100
# arr_orig_wav_n size [1, 2930000] orig fs 44100
# arr_orig_wav_n size [1, 2925000] orig fs 44100
# arr_orig_wav_n size [1, 2765000] orig fs 44100
# arr_orig_wav_n size [1, 2895000] orig fs 44100
# arr_orig_wav_n size [1, 3095000] orig fs 44100
# arr_orig_wav_n size [1, 2940000] orig fs 44100
# arr_orig_wav_n size [1, 2805000] orig fs 44100
# arr_orig_wav_n size [1, 2985000] orig fs 44100
# arr_orig_wav_n size [1, 2950000] orig fs 44100
# arr_orig_wav_n size [1, 2935000] orig fs 44100
# arr_orig_wav_n size [1, 3100000] orig fs 44100
# arr_orig_wav_n size [1, 2985000] orig fs 44100
# arr_orig_wav_n size [1, 2885000] orig fs 44100
# arr_orig_wav_n size [1, 3230000] orig fs 44100
# arr_orig_wav_n size [1, 2940000] orig fs 44100
# arr_orig_wav_n size [1, 3410000] orig fs 44100
# arr_orig_wav_n size [1, 2775000] orig fs 44100
# arr_orig_wav_n size [1, 3150000] orig fs 44100
# arr_orig_wav_n size [1, 2720000] orig fs 44100
# arr_orig_wav_n size [1, 2925000] orig fs 44100
# arr_orig_wav_n size [1, 2990000] orig fs 44100
# arr_orig_wav_n size [1, 2730000] orig fs 44100
# arr_orig_wav_n size [1, 2745000] orig fs 44100
# arr_orig_wav_n size [1, 2700000] orig fs 44100
# arr_orig_wav_n size [1, 2900000] orig fs 44100
# arr_orig_wav_n size [1, 2740000] orig fs 44100
# arr_orig_wav_n size [1, 3030000] orig fs 44100
# arr_orig_wav_n size [1, 4375000] orig fs 44100
# arr_orig_wav_n size [1, 3655000] orig fs 44100
# arr_orig_wav_n size [1, 3550000] orig fs 44100
# arr_orig_wav_n size [1, 2885000] orig fs 44100
# arr_orig_wav_n size [1, 2990000] orig fs 44100
# arr_orig_wav_n size [1, 2880000] orig fs 44100
# arr_orig_wav_n size [1, 3305000] orig fs 44100
# arr_orig_wav_n size [1, 2940000] orig fs 44100
# arr_orig_wav_n size [1, 3045000] orig fs 44100
# arr_orig_wav_n size [1, 3070000] orig fs 44100
# arr_orig_wav_n size [1, 2810000] orig fs 44100
# arr_orig_wav_n size [1, 3310000] orig fs 44100
# arr_orig_wav_n size [1, 3055000] orig fs 44100
# arr_orig_wav_n size [1, 3100000] orig fs 44100
# arr_orig_wav_n size [1, 3295000] orig fs 44100
# arr_orig_wav_n size [1, 3100000] orig fs 44100
# arr_orig_wav_n size [1, 2885000] orig fs 44100
# arr_orig_wav_n size [1, 2935000] orig fs 44100
# arr_orig_wav_n size [1, 2970000] orig fs 44100
# arr_orig_wav_n size [1, 2755000] orig fs 44100
# arr_orig_wav_n size [1, 3120000] orig fs 44100
# arr_orig_wav_n size [1, 3120000] orig fs 44100
# arr_orig_wav_n size [1, 2855000] orig fs 44100
# arr_orig_wav_n size [1, 2710000] orig fs 44100
# arr_orig_wav_n size [1, 2745000] orig fs 44100
# arr_orig_wav_n size [1, 2820000] orig fs 44100
# arr_orig_wav_n size [1, 3145000] orig fs 44100
# arr_orig_wav_n size [1, 2730000] orig fs 44100
# arr_orig_wav_n size [1, 2745000] orig fs 44100
# arr_orig_wav_n size [1, 2730000] orig fs 44100
# arr_orig_wav_n size [1, 3445000] orig fs 44100
# arr_orig_wav_n size [1, 2880000] orig fs 44100
# arr_orig_wav_n size [1, 3065000] orig fs 44100
# arr_orig_wav_n size [1, 2905000] orig fs 44100
# arr_orig_wav_n size [1, 2720000] orig fs 44100
# arr_orig_wav_n size [1, 3010000] orig fs 44100
# arr_orig_wav_n size [1, 3035000] orig fs 44100
# arr_orig_wav_n size [1, 2715000] orig fs 44100
# arr_orig_wav_n size [1, 2800000] orig fs 44100
# arr_orig_wav_n size [1, 2735000] orig fs 44100
# arr_orig_wav_n size [1, 2825000] orig fs 44100
# arr_orig_wav_n size [1, 3085000] orig fs 44100
# arr_orig_wav_n size [1, 2785000] orig fs 44100
# arr_orig_wav_n size [1, 2785000] orig fs 44100
# arr_orig_wav_n size [1, 2715000] orig fs 44100
# arr_orig_wav_n size [1, 2825000] orig fs 44100
# arr_orig_wav_n size [1, 2815000] orig fs 44100
# arr_orig_wav_n size [1, 2665000] orig fs 44100
# arr_orig_wav_n size [1, 2720000] orig fs 44100
# arr_orig_wav_n size [1, 2970000] orig fs 44100
# arr_orig_wav_n size [1, 3080000] orig fs 44100
# arr_orig_wav_n size [1, 2875000] orig fs 44100
# arr_orig_wav_n size [1, 2925000] orig fs 44100
# arr_orig_wav_n size [1, 3020000] orig fs 44100
# arr_orig_wav_n size [1, 2845000] orig fs 44100
# arr_orig_wav_n size [1, 3130000] orig fs 44100
# arr_orig_wav_n size [1, 3385000] orig fs 44100
# arr_orig_wav_n size [1, 2760000] orig fs 44100
# arr_orig_wav_n size [1, 2825000] orig fs 44100
# arr_orig_wav_n size [1, 2750000] orig fs 44100
# arr_orig_wav_n size [1, 3010000] orig fs 44100
# arr_orig_wav_n size [1, 2870000] orig fs 44100
# arr_orig_wav_n size [1, 2780000] orig fs 44100
# arr_orig_wav_n size [1, 2980000] orig fs 44100
# arr_orig_wav_n size [1, 2840000] orig fs 44100
# arr_orig_wav_n size [1, 2910000] orig fs 44100
# arr_orig_wav_n size [1, 2980000] orig fs 44100
# arr_orig_wav_n size [1, 2735000] orig fs 44100
# arr_orig_wav_n size [1, 3335000] orig fs 44100
# arr_orig_wav_n size [1, 2735000] orig fs 44100
# arr_orig_wav_n size [1, 3085000] orig fs 44100
# arr_orig_wav_n size [1, 2985000] orig fs 44100
# arr_orig_wav_n size [1, 3220000] orig fs 44100
# arr_orig_wav_n size [1, 3160000] orig fs 44100
# arr_orig_wav_n size [1, 3175000] orig fs 44100
# arr_orig_wav_n size [1, 2890000] orig fs 44100
# arr_orig_wav_n size [1, 2915000] orig fs 44100
# arr_orig_wav_n size [1, 2775000] orig fs 44100
# arr_orig_wav_n size [1, 2780000] orig fs 44100
# arr_orig_wav_n size [1, 2775000] orig fs 44100
# arr_orig_wav_n size [1, 2985000] orig fs 44100
# arr_orig_wav_n size [1, 2805000] orig fs 44100
# arr_orig_wav_n size [1, 2785000] orig fs 44100
# arr_orig_wav_n size [1, 2825000] orig fs 44100
# arr_orig_wav_n size [1, 2770000] orig fs 44100
# arr_orig_wav_n size [1, 3945000] orig fs 44100
# arr_orig_wav_n size [1, 3130000] orig fs 44100
# arr_orig_wav_n size [1, 2805000] orig fs 44100
# arr_orig_wav_n size [1, 2780000] orig fs 44100
# arr_orig_wav_n size [1, 2715000] orig fs 44100
# arr_orig_wav_n size [1, 3030000] orig fs 44100
# arr_orig_wav_n size [1, 3025000] orig fs 44100
# arr_orig_wav_n size [1, 3160000] orig fs 44100
# arr_orig_wav_n size [1, 3095000] orig fs 44100
# arr_orig_wav_n size [1, 3070000] orig fs 44100
# arr_orig_wav_n size [1, 2950000] orig fs 44100
# arr_orig_wav_n size [1, 2925000] orig fs 44100
# arr_orig_wav_n size [1, 2755000] orig fs 44100
# arr_orig_wav_n size [1, 2805000] orig fs 44100
# arr_orig_wav_n size [1, 2855000] orig fs 44100
# arr_orig_wav_n size [1, 3015000] orig fs 44100
# arr_orig_wav_n size [1, 2955000] orig fs 44100
# arr_orig_wav_n size [1, 2790000] orig fs 44100
# arr_orig_wav_n size [1, 2955000] orig fs 44100
# arr_orig_wav_n size [1, 2960000] orig fs 44100
# arr_orig_wav_n size [1, 3100000] orig fs 44100
# arr_orig_wav_n size [1, 2855000] orig fs 44100
# arr_orig_wav_n size [1, 2715000] orig fs 44100
# arr_orig_wav_n size [1, 2940000] orig fs 44100
# arr_orig_wav_n size [1, 2970000] orig fs 44100
# arr_orig_wav_n size [1, 3070000] orig fs 44100
# arr_orig_wav_n size [1, 2800000] orig fs 44100
# arr_orig_wav_n size [1, 2765000] orig fs 44100
# arr_orig_wav_n size [1, 2820000] orig fs 44100
# arr_orig_wav_n size [1, 2810000] orig fs 44100
# arr_orig_wav_n size [1, 3070000] orig fs 44100
# arr_orig_wav_n size [1, 3160000] orig fs 44100
# arr_orig_wav_n size [1, 2730000] orig fs 44100
# arr_orig_wav_n size [1, 2825000] orig fs 44100
# arr_orig_wav_n size [1, 2760000] orig fs 44100
# arr_orig_wav_n size [1, 3075000] orig fs 44100
# arr_orig_wav_n size [1, 3110000] orig fs 44100
# arr_orig_wav_n size [1, 2830000] orig fs 44100
# arr_orig_wav_n size [1, 2800000] orig fs 44100
# arr_orig_wav_n size [1, 2790000] orig fs 44100
# arr_orig_wav_n size [1, 3005000] orig fs 44100
# arr_orig_wav_n size [1, 2870000] orig fs 44100
# arr_orig_wav_n size [1, 2790000] orig fs 44100
# arr_orig_wav_n size [1, 2830000] orig fs 44100
# arr_orig_wav_n size [1, 2865000] orig fs 44100
# arr_orig_wav_n size [1, 2855000] orig fs 44100
# arr_orig_wav_n size [1, 2850000] orig fs 44100
# arr_orig_wav_n size [1, 2845000] orig fs 44100
# arr_orig_wav_n size [1, 2930000] orig fs 44100
# arr_orig_wav_n size [1, 2750000] orig fs 44100
# arr_orig_wav_n size [1, 3130000] orig fs 44100
# arr_orig_wav_n size [1, 2855000] orig fs 44100
# arr_orig_wav_n size [1, 2810000] orig fs 44100
# arr_orig_wav_n size [1, 2670000] orig fs 44100
# arr_orig_wav_n size [1, 2745000] orig fs 44100
# arr_orig_wav_n size [1, 2915000] orig fs 44100
# arr_orig_wav_n size [1, 3000000] orig fs 44100
# arr_orig_wav_n size [1, 2720000] orig fs 44100
# arr_orig_wav_n size [1, 2775000] orig fs 44100
# arr_orig_wav_n size [1, 2720000] orig fs 44100
# arr_orig_wav_n size [1, 2890000] orig fs 44100
# arr_orig_wav_n size [1, 2980000] orig fs 44100
# arr_orig_wav_n size [1, 2870000] orig fs 44100
# arr_orig_wav_n size [1, 2760000] orig fs 44100
# arr_orig_wav_n size [1, 2730000] orig fs 44100
# arr_orig_wav_n size [1, 2795000] orig fs 44100
# arr_orig_wav_n size [1, 2900000] orig fs 44100
# arr_orig_wav_n size [1, 3340000] orig fs 44100
# arr_orig_wav_n size [1, 3120000] orig fs 44100
# arr_orig_wav_n size [1, 2860000] orig fs 44100
# arr_orig_wav_n size [1, 3570000] orig fs 44100
# arr_orig_wav_n size [1, 2840000] orig fs 44100
# arr_orig_wav_n size [1, 2725000] orig fs 44100
# arr_orig_wav_n size [1, 2670000] orig fs 44100
# arr_orig_wav_n size [1, 2670000] orig fs 44100
# arr_orig_wav_n size [1, 3305000] orig fs 44100
# arr_orig_wav_n size [1, 4075000] orig fs 44100
# arr_orig_wav_n size [1, 2760000] orig fs 44100
# arr_orig_wav_n size [1, 2850000] orig fs 44100
# arr_orig_wav_n size [1, 2770000] orig fs 44100
# arr_orig_wav_n size [1, 2895000] orig fs 44100
# arr_orig_wav_n size [1, 2845000] orig fs 44100
# arr_orig_wav_n size [1, 2805000] orig fs 44100
# arr_orig_wav_n size [1, 2760000] orig fs 44100
# arr_orig_wav_n size [1, 2810000] orig fs 44100
# arr_orig_wav_n size [1, 2810000] orig fs 44100
# arr_orig_wav_n size [1, 2785000] orig fs 44100
# arr_orig_wav_n size [1, 2830000] orig fs 44100
# arr_orig_wav_n size [1, 3010000] orig fs 44100
# arr_orig_wav_n size [1, 2870000] orig fs 44100
# arr_orig_wav_n size [1, 3065000] orig fs 44100
# arr_orig_wav_n size [1, 2975000] orig fs 44100
# arr_orig_wav_n size [1, 2825000] orig fs 44100
# arr_orig_wav_n size [1, 2820000] orig fs 44100
# arr_orig_wav_n size [1, 2890000] orig fs 44100
# arr_orig_wav_n size [1, 2870000] orig fs 44100
# arr_orig_wav_n size [1, 2855000] orig fs 44100
# arr_orig_wav_n size [1, 2985000] orig fs 44100
# arr_orig_wav_n size [1, 2670000] orig fs 44100
# arr_orig_wav_n size [1, 2715000] orig fs 44100
# arr_orig_wav_n size [1, 3045000] orig fs 44100
# arr_orig_wav_n size [1, 2935000] orig fs 44100
# arr_orig_wav_n size [1, 2815000] orig fs 44100
# arr_orig_wav_n size [1, 3080000] orig fs 44100
# arr_orig_wav_n size [1, 3100000] orig fs 44100
# arr_orig_wav_n size [1, 3305000] orig fs 44100
# arr_orig_wav_n size [1, 3135000] orig fs 44100
# arr_orig_wav_n size [1, 2730000] orig fs 44100
# arr_orig_wav_n size [1, 3195000] orig fs 44100
# arr_orig_wav_n size [1, 2730000] orig fs 44100
# arr_orig_wav_n size [1, 2935000] orig fs 44100
# arr_orig_wav_n size [1, 2840000] orig fs 44100
# arr_orig_wav_n size [1, 2700000] orig fs 44100
# arr_orig_wav_n size [1, 2795000] orig fs 44100
# arr_orig_wav_n size [1, 2825000] orig fs 44100
# arr_orig_wav_n size [1, 2985000] orig fs 44100
# arr_orig_wav_n size [1, 3545000] orig fs 44100
# arr_orig_wav_n size [1, 2860000] orig fs 44100
# arr_orig_wav_n size [1, 2775000] orig fs 44100
# arr_orig_wav_n size [1, 2775000] orig fs 44100
# arr_orig_wav_n size [1, 3290000] orig fs 44100
# arr_orig_wav_n size [1, 3075000] orig fs 44100
# arr_orig_wav_n size [1, 2855000] orig fs 44100
# arr_orig_wav_n size [1, 2725000] orig fs 44100
# arr_orig_wav_n size [1, 2765000] orig fs 44100
# arr_orig_wav_n size [1, 2970000] orig fs 44100
# arr_orig_wav_n size [1, 3110000] orig fs 44100
# arr_orig_wav_n size [1, 2930000] orig fs 44100
# arr_orig_wav_n size [1, 3565000] orig fs 44100
# arr_orig_wav_n size [1, 3210000] orig fs 44100
# arr_orig_wav_n size [1, 2960000] orig fs 44100
# arr_orig_wav_n size [1, 2990000] orig fs 44100
# arr_orig_wav_n size [1, 2755000] orig fs 44100
# arr_orig_wav_n size [1, 2820000] orig fs 44100
# arr_orig_wav_n size [1, 2900000] orig fs 44100
# arr_orig_wav_n size [1, 3135000] orig fs 44100
# arr_orig_wav_n size [1, 2860000] orig fs 44100
# arr_orig_wav_n size [1, 2840000] orig fs 44100
# arr_orig_wav_n size [1, 3285000] orig fs 44100
# arr_orig_wav_n size [1, 2910000] orig fs 44100
# arr_orig_wav_n size [1, 3210000] orig fs 44100
# arr_orig_wav_n size [1, 3030000] orig fs 44100
# arr_orig_wav_n size [1, 2825000] orig fs 44100
# arr_orig_wav_n size [1, 2690000] orig fs 44100
# arr_orig_wav_n size [1, 2710000] orig fs 44100
# arr_orig_wav_n size [1, 3045000] orig fs 44100
# arr_orig_wav_n size [1, 2760000] orig fs 44100
# arr_orig_wav_n size [1, 2905000] orig fs 44100
# arr_orig_wav_n size [1, 2955000] orig fs 44100
# arr_orig_wav_n size [1, 2745000] orig fs 44100
# arr_orig_wav_n size [1, 2765000] orig fs 44100
# arr_orig_wav_n size [1, 2880000] orig fs 44100

# %% [markdown]
# ## Analyze a single utterance

# %%
analyze_wav = wavs[115]

# %%
a = np.arange(10)

# %%
analyze_utterance(
    analyze_wav,
    audio=False,
    plot_type="dash",
    noise_factor=0, # 1 / (2**12),
    show_noise_audio=False,
    listen_noise_audio=True,
)
# Out:
# arr_orig_wav_n size [1, 2770000] orig fs 44100
# GridspecLayout(children=(Output(layout=Layout(grid_area='widget001')), Output(layout=Layout(grid_area='widget0…
#         <iframe
#             width="100%"
#             height="968"
#             src="http://127.0.0.1:8054/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# analyze_utterance(
#     analyze_wav,
#     audio=False,
#     plot_type="dash",
#     noise_factor=1 / (2**12),
#     smile_lld=opensmile.Smile(
#         feature_set=opensmile.FeatureSet.ComParE_2016,
#         feature_level=opensmile.FeatureLevel.LowLevelDescriptors,
#     ),
#     feat_cols=[
#         "F0final_sma",
#         "voicingFinalUnclipped_sma",
#         "jitterLocal_sma",
#         "shimmerLocal_sma",
#         "logHNR_sma",
#     ],
# )

# %%
# load and play the audio
starts, end_s = 22, 28

wav, sr = torchaudio.load(analyze_wav)
wav = wav.numpy().ravel()
Audio(wav[int(sr * starts): int(sr * end_s)], rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
