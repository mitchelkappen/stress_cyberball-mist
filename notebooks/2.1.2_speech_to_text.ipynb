# %% [markdown]
# # Performing speech-to-text on files

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pathlib import Path
from tqdm.auto import tqdm
import pandas as pd
from IPython.display import display
import numpy as np
import os
import whisper
import time

import speech_recognition as sr
# import cloudstorage as gcs

# %%
# configure user
user = "mitchel"
extracted_feats = True

if user.lower() == "jonas":
    BASE_PATH = Path("/users/jonvdrdo/jonas/data/aaa_contextaware/raw/uz_study/")
elif user.lower() == "mitchel":
#     BASE_PATH = Path("Z:/shares/ghep_lab/2021_VanhollebekeKappen_EEGStudy2_MIST_Cyberball_Audio/")
    BASE_PATH = Path("E:/Data/EEG_Study_2")
DATA_PATH = BASE_PATH.joinpath("Data/Raw/Audio")

# %%
os.chdir(DATA_PATH)
# os.listdir()
# os.getcwd()

# %%
# help(whisper.transcribe)
import os, random
random.choice(os.listdir())

allFileNames = ["audio_picture_baseline.wav", "audio_picture_control.wav", "audio_picture_stress.wav", "audio_referential_control.wav", "audio_referential_stress.wav"]
filedir = random.choice(os.listdir())
audiofiledir = random.choice(allFileNames)

filedir + '/' + audiofiledir
# Out:
# 'ppt_31_cybb_speech/audio_referential_stress.wav'

# %%
# https://www.thepythoncode.com/article/using-speech-recognition-to-convert-speech-to-text-python
fname = "E:/Data/EEG_Study_2/Data/Raw/Audio/ppt_8_mist_speech/audio_referential_control.wav"

# open the file
model = whisper.load_model("base")
# result = model.transcribe("audio_referential_control.wav")
# print(result["text"])
for files in os.listdir():
    print(files)
    result = model.transcribe(files)
    print(result["text"])
    break

# %% [markdown]
# # Test quality/time tradeoff between different model sizes

# %%
allFileNames = ["audio_picture_baseline.wav", "audio_picture_control.wav", "audio_picture_stress.wav", "audio_referential_control.wav", "audio_referential_stress.wav"]
modeltypes = ["tiny","base","small","medium"] # Different model types we will loop over
# Pre-create the lists where we'll store information
models = []
transcripts = []
timings = []
language = []
pptdir = []
filenames = []

filenumberCount = 30

for x in range(0,30):
    filedir = random.choice(os.listdir())
    audiofiledir = random.choice(allFileNames)
    print("Currently running: " + filedir + '/' + audiofiledir)
    
    for modeltype in modeltypes:
        print("Currently running: " + modeltype)
        model = whisper.load_model(modeltype)
        t = time.time()
        result = model.transcribe(filedir + '/' + audiofiledir)
        elapsed = time.time() - t

        models.append(modeltype)
        transcripts.append(result["text"])
        timings.append(elapsed)
        language.append(result["language"])
        pptdir.append(filedir)
        filenames.append(audiofiledir)
    
df = pd.DataFrame({'PptDir': pptdir, 'FileName': filenames, 'Modeltype': models, 'Transcripts': transcripts, 'TimeElapsed': timings, 'Language': language})
df

df.to_csv('C:/Users/mitch/OneDrive - UGent/Documents/GitHub/stress_cyberball-mist/transcripts/transcriptModelTest2.csv')
# Out:
# Currently running: ppt_40_cybb_speech/audio_picture_stress.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_37_mist_speech/audio_picture_baseline.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_14_cybb_speech/audio_referential_stress.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_25_mist_speech/audio_picture_baseline.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_37_cybb_speech/audio_picture_baseline.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_45_cybb_speech/audio_referential_stress.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_29_mist_speech/audio_picture_baseline.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_61_mist_speech/audio_referential_stress.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_32_mist_speech/audio_picture_baseline.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_24_mist_speech/audio_picture_stress.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_64_mist_speech/audio_picture_control.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_36_cybb_speech/audio_picture_baseline.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_28_mist_speech/audio_referential_stress.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_70_mist_speech/audio_picture_control.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_31_cybb_speech/audio_picture_stress.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_8_cybb_speech/audio_picture_control.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_61_cybb_speech/audio_picture_control.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_64_mist_speech/audio_referential_stress.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_32_cybb_speech/audio_referential_control.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_5_cybb_speech/audio_referential_stress.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_62_cybb_speech/audio_referential_control.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_51_cybb_speech/audio_picture_control.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_5_mist_speech/audio_referential_stress.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_46_mist_speech/audio_picture_stress.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_69_cybb_speech/audio_picture_baseline.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_10_cybb_speech/audio_picture_control.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_6_mist_speech/audio_referential_control.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_29_mist_speech/audio_picture_stress.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_42_mist_speech/audio_picture_baseline.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium
# Currently running: ppt_72_mist_speech/audio_picture_baseline.wav
# Currently running: tiny
# Currently running: base
# Currently running: small
# Currently running: medium

# %%
result
# Out:
# {'text': ' Ik zie twee mensen aan tafel, een vrouw en een man. Ik vermoed een koppel. De man heeft het menukaart vast. Rechts van hun is een vrouw hun bestellingen aan het opnemen. De man kijkt naar zijn vrouw, vermoed ik. De man heeft een polo aan met korte mouwen. De vrouw heeft een topje aan. Het koppel heeft allebei kort haar. De vrouw die de bestelling aan het opnemen is, heeft ook een polo aan met een badge boven haar borst. De vrouw die de bestelling aan het opnemen is, heeft een dotje aan.',
#  'segments': [{'id': 0,
#    'seek': 0,
#    'start': 0.0,
#    'end': 4.6000000000000005,
#    'text': ' Ik zie twee mensen aan tafel, een vrouw en een man.',
#    'tokens': [50364,
#     8316,
#     16503,
#     30660,
#     18062,
#     9904,
#     1846,
#     29874,
#     11,
#     3881,
#     371,
#     13122,
#     86,
#     465,
#     3881,
#     587,
#     13,
#     50594,
#     50598,
#     8316,
#     1306,
#     3280,
#     292,
#     3881,
#     350,
#     17158,
#     338,
#     13,
#     50678,
#     50682,
#     1346,
#     587,
#     17425,
#     3639,
#     6510,
#     2330,
#     446,
#     8369,
#     13,
#     50806,
#     50906,
#     36597,
#     3161,
#     7396,
#     307,
#     3881,
#     371,
#     13122,
#     86,
#     7396,
#     1151,
#     11073,
#     268,
#     9904,
#     3639,
#     999,
#     77,
#     14071,
#     13,
#     51156,
#     51218,
#     1346,
#     587,
#     26106,
#     2320,
#     12762,
#     8004,
#     371,
#     13122,
#     86,
#     11,
#     1306,
#     3280,
#     292,
#     4320,
#     13,
#     51382,
#     51414,
#     1346,
#     587,
#     17425,
#     3881,
#     1180,
#     78,
#     9904,
#     1131,
#     350,
#     12752,
#     275,
#     263,
#     15615,
#     13,
#     51634,
#     51732,
#     1346,
#     371,
#     13122,
#     86,
#     17425,
#     3881,
#     1192,
#     2884,
#     9904,
#     13,
#     51826],
#    'temperature': 0.0,
#    'avg_logprob': -0.27751400785626107,
#    'compression_ratio': 1.7065868263473054,
#    'no_speech_prob': 0.2661084234714508},
#   {'id': 1,
#    'seek': 0,
#    'start': 4.68,
#    'end': 6.28,
#    'text': ' Ik vermoed een koppel.',
#    'tokens': [50364,
#     8316,
#     16503,
#     30660,
#     18062,
#     9904,
#     1846,
#     29874,
#     11,
#     3881,
#     371,
#     13122,
#     86,
#     465,
#     3881,
#     587,
#     13,
#     50594,
#     50598,
#     8316,
#     1306,
#     3280,
#     292,
#     3881,
#     350,
#     17158,
#     338,
#     13,
#     50678,
#     50682,
#     1346,
#     587,
#     17425,
#     3639,
#     6510,
#     2330,
#     446,
#     8369,
#     13,
#     50806,
#     50906,
#     36597,
#     3161,
#     7396,
#     307,
#     3881,
#     371,
#     13122,
#     86,
#     7396,
#     1151,
#     11073,
#     268,
#     9904,
#     3639,
#     999,
#     77,
#     14071,
#     13,
#     51156,
#     51218,
#     1346,
#     587,
#     26106,
#     2320,
#     12762,
#     8004,
#     371,
#     13122,
#     86,
#     11,
#     1306,
#     3280,
#     292,
#     4320,
#     13,
#     51382,
#     51414,
#     1346,
#     587,
#     17425,
#     3881,
#     1180,
#     78,
#     9904,
#     1131,
#     350,
#     12752,
#     275,
#     263,
#     15615,
#     13,
#     51634,
#     51732,
#     1346,
#     371,
#     13122,
#     86,
#     17425,
#     3881,
#     1192,
#     2884,
#     9904,
#     13,
#     51826],
#    'temperature': 0.0,
#    'avg_logprob': -0.27751400785626107,
#    'compression_ratio': 1.7065868263473054,
#    'no_speech_prob': 0.2661084234714508},
#   {'id': 2,
#    'seek': 0,
#    'start': 6.36,
#    'end': 8.84,
#    'text': ' De man heeft het menukaart vast.',
#    'tokens': [50364,
#     8316,
#     16503,
#     30660,
#     18062,
#     9904,
#     1846,
#     29874,
#     11,
#     3881,
#     371,
#     13122,
#     86,
#     465,
#     3881,
#     587,
#     13,
#     50594,
#     50598,
#     8316,
#     1306,
#     3280,
#     292,
#     3881,
#     350,
#     17158,
#     338,
#     13,
#     50678,
#     50682,
#     1346,
#     587,
#     17425,
#     3639,
#     6510,
#     2330,
#     446,
#     8369,
#     13,
#     50806,
#     50906,
#     36597,
#     3161,
#     7396,
#     307,
#     3881,
#     371,
#     13122,
#     86,
#     7396,
#     1151,
#     11073,
#     268,
#     9904,
#     3639,
#     999,
#     77,
#     14071,
#     13,
#     51156,
#     51218,
#     1346,
#     587,
#     26106,
#     2320,
#     12762,
#     8004,
#     371,
#     13122,
#     86,
#     11,
#     1306,
#     3280,
#     292,
#     4320,
#     13,
#     51382,
#     51414,
#     1346,
#     587,
#     17425,
#     3881,
#     1180,
#     78,
#     9904,
#     1131,
#     350,
#     12752,
#     275,
#     263,
#     15615,
#     13,
#     51634,
#     51732,
#     1346,
#     371,
#     13122,
#     86,
#     17425,
#     3881,
#     1192,
#     2884,
#     9904,
#     13,
#     51826],
#    'temperature': 0.0,
#    'avg_logprob': -0.27751400785626107,
#    'compression_ratio': 1.7065868263473054,
#    'no_speech_prob': 0.2661084234714508},
#   {'id': 3,
#    'seek': 0,
#    'start': 10.84,
#    'end': 15.84,
#    'text': ' Rechts van hun is een vrouw hun bestellingen aan het opnemen.',
#    'tokens': [50364,
#     8316,
#     16503,
#     30660,
#     18062,
#     9904,
#     1846,
#     29874,
#     11,
#     3881,
#     371,
#     13122,
#     86,
#     465,
#     3881,
#     587,
#     13,
#     50594,
#     50598,
#     8316,
#     1306,
#     3280,
#     292,
#     3881,
#     350,
#     17158,
#     338,
#     13,
#     50678,
#     50682,
#     1346,
#     587,
#     17425,
#     3639,
#     6510,
#     2330,
#     446,
#     8369,
#     13,
#     50806,
#     50906,
#     36597,
#     3161,
#     7396,
#     307,
#     3881,
#     371,
#     13122,
#     86,
#     7396,
#     1151,
#     11073,
#     268,
#     9904,
#     3639,
#     999,
#     77,
#     14071,
#     13,
#     51156,
#     51218,
#     1346,
#     587,
#     26106,
#     2320,
#     12762,
#     8004,
#     371,
#     13122,
#     86,
#     11,
#     1306,
#     3280,
#     292,
#     4320,
#     13,
#     51382,
#     51414,
#     1346,
#     587,
#     17425,
#     3881,
#     1180,
#     78,
#     9904,
#     1131,
#     350,
#     12752,
#     275,
#     263,
#     15615,
#     13,
#     51634,
#     51732,
#     1346,
#     371,
#     13122,
#     86,
#     17425,
#     3881,
#     1192,
#     2884,
#     9904,
#     13,
#     51826],
#    'temperature': 0.0,
#    'avg_logprob': -0.27751400785626107,
#    'compression_ratio': 1.7065868263473054,
#    'no_speech_prob': 0.2661084234714508},
#   {'id': 4,
#    'seek': 0,
#    'start': 17.080000000000002,
#    'end': 20.36,
#    'text': ' De man kijkt naar zijn vrouw, vermoed ik.',
#    'tokens': [50364,
#     8316,
#     16503,
#     30660,
#     18062,
#     9904,
#     1846,
#     29874,
#     11,
#     3881,
#     371,
#     13122,
#     86,
#     465,
#     3881,
#     587,
#     13,
#     50594,
#     50598,
#     8316,
#     1306,
#     3280,
#     292,
#     3881,
#     350,
#     17158,
#     338,
#     13,
#     50678,
#     50682,
#     1346,
#     587,
#     17425,
#     3639,
#     6510,
#     2330,
#     446,
#     8369,
#     13,
#     50806,
#     50906,
#     36597,
#     3161,
#     7396,
#     307,
#     3881,
#     371,
#     13122,
#     86,
#     7396,
#     1151,
#     11073,
#     268,
#     9904,
#     3639,
#     999,
#     77,
#     14071,
#     13,
#     51156,
#     51218,
#     1346,
#     587,
#     26106,
#     2320,
#     12762,
#     8004,
#     371,
#     13122,
#     86,
#     11,
#     1306,
#     3280,
#     292,
#     4320,
#     13,
#     51382,
#     51414,
#     1346,
#     587,
#     17425,
#     3881,
#     1180,
#     78,
#     9904,
#     1131,
#     350,
#     12752,
#     275,
#     263,
#     15615,
#     13,
#     51634,
#     51732,
#     1346,
#     371,
#     13122,
#     86,
#     17425,
#     3881,
#     1192,
#     2884,
#     9904,
#     13,
#     51826],
#    'temperature': 0.0,
#    'avg_logprob': -0.27751400785626107,
#    'compression_ratio': 1.7065868263473054,
#    'no_speech_prob': 0.2661084234714508},
#   {'id': 5,
#    'seek': 0,
#    'start': 21.0,
#    'end': 25.400000000000002,
#    'text': ' De man heeft een polo aan met korte mouwen.',
#    'tokens': [50364,
#     8316,
#     16503,
#     30660,
#     18062,
#     9904,
#     1846,
#     29874,
#     11,
#     3881,
#     371,
#     13122,
#     86,
#     465,
#     3881,
#     587,
#     13,
#     50594,
#     50598,
#     8316,
#     1306,
#     3280,
#     292,
#     3881,
#     350,
#     17158,
#     338,
#     13,
#     50678,
#     50682,
#     1346,
#     587,
#     17425,
#     3639,
#     6510,
#     2330,
#     446,
#     8369,
#     13,
#     50806,
#     50906,
#     36597,
#     3161,
#     7396,
#     307,
#     3881,
#     371,
#     13122,
#     86,
#     7396,
#     1151,
#     11073,
#     268,
#     9904,
#     3639,
#     999,
#     77,
#     14071,
#     13,
#     51156,
#     51218,
#     1346,
#     587,
#     26106,
#     2320,
#     12762,
#     8004,
#     371,
#     13122,
#     86,
#     11,
#     1306,
#     3280,
#     292,
#     4320,
#     13,
#     51382,
#     51414,
#     1346,
#     587,
#     17425,
#     3881,
#     1180,
#     78,
#     9904,
#     1131,
#     350,
#     12752,
#     275,
#     263,
#     15615,
#     13,
#     51634,
#     51732,
#     1346,
#     371,
#     13122,
#     86,
#     17425,
#     3881,
#     1192,
#     2884,
#     9904,
#     13,
#     51826],
#    'temperature': 0.0,
#    'avg_logprob': -0.27751400785626107,
#    'compression_ratio': 1.7065868263473054,
#    'no_speech_prob': 0.2661084234714508},
#   {'id': 6,
#    'seek': 2540,
#    'start': 25.4,
#    'end': 29.04,
#    'text': ' De vrouw heeft een topje aan.',
#    'tokens': [50364,
#     1346,
#     371,
#     13122,
#     86,
#     17425,
#     3881,
#     1192,
#     2884,
#     9904,
#     13,
#     50546,
#     50726,
#     12045,
#     350,
#     17158,
#     338,
#     17425,
#     5430,
#     21845,
#     46980,
#     39371,
#     13,
#     50874,
#     50986,
#     1346,
#     371,
#     13122,
#     86,
#     978,
#     368,
#     1151,
#     11073,
#     9904,
#     3639,
#     999,
#     77,
#     14071,
#     307,
#     11,
#     51136,
#     51140,
#     17425,
#     7839,
#     3881,
#     1180,
#     78,
#     9904,
#     1131,
#     3881,
#     25797,
#     748,
#     553,
#     39371,
#     14828,
#     372,
#     13,
#     51368,
#     51492,
#     1346,
#     371,
#     13122,
#     86,
#     978,
#     368,
#     1151,
#     11073,
#     9904,
#     3639,
#     999,
#     77,
#     14071,
#     307,
#     11,
#     51706,
#     51744,
#     17425,
#     3881,
#     5893,
#     2884,
#     9904,
#     13,
#     51846],
#    'temperature': 0.0,
#    'avg_logprob': -0.33242393675304593,
#    'compression_ratio': 1.8359375,
#    'no_speech_prob': 3.862684479827294e-06},
#   {'id': 7,
#    'seek': 2540,
#    'start': 32.64,
#    'end': 35.6,
#    'text': ' Het koppel heeft allebei kort haar.',
#    'tokens': [50364,
#     1346,
#     371,
#     13122,
#     86,
#     17425,
#     3881,
#     1192,
#     2884,
#     9904,
#     13,
#     50546,
#     50726,
#     12045,
#     350,
#     17158,
#     338,
#     17425,
#     5430,
#     21845,
#     46980,
#     39371,
#     13,
#     50874,
#     50986,
#     1346,
#     371,
#     13122,
#     86,
#     978,
#     368,
#     1151,
#     11073,
#     9904,
#     3639,
#     999,
#     77,
#     14071,
#     307,
#     11,
#     51136,
#     51140,
#     17425,
#     7839,
#     3881,
#     1180,
#     78,
#     9904,
#     1131,
#     3881,
#     25797,
#     748,
#     553,
#     39371,
#     14828,
#     372,
#     13,
#     51368,
#     51492,
#     1346,
#     371,
#     13122,
#     86,
#     978,
#     368,
#     1151,
#     11073,
#     9904,
#     3639,
#     999,
#     77,
#     14071,
#     307,
#     11,
#     51706,
#     51744,
#     17425,
#     3881,
#     5893,
#     2884,
#     9904,
#     13,
#     51846],
#    'temperature': 0.0,
#    'avg_logprob': -0.33242393675304593,
#    'compression_ratio': 1.8359375,
#    'no_speech_prob': 3.862684479827294e-06},
#   {'id': 8,
#    'seek': 2540,
#    'start': 37.839999999999996,
#    'end': 40.839999999999996,
#    'text': ' De vrouw die de bestelling aan het opnemen is,',
#    'tokens': [50364,
#     1346,
#     371,
#     13122,
#     86,
#     17425,
#     3881,
#     1192,
#     2884,
#     9904,
#     13,
#     50546,
#     50726,
#     12045,
#     350,
#     17158,
#     338,
#     17425,
#     5430,
#     21845,
#     46980,
#     39371,
#     13,
#     50874,
#     50986,
#     1346,
#     371,
#     13122,
#     86,
#     978,
#     368,
#     1151,
#     11073,
#     9904,
#     3639,
#     999,
#     77,
#     14071,
#     307,
#     11,
#     51136,
#     51140,
#     17425,
#     7839,
#     3881,
#     1180,
#     78,
#     9904,
#     1131,
#     3881,
#     25797,
#     748,
#     553,
#     39371,
#     14828,
#     372,
#     13,
#     51368,
#     51492,
#     1346,
#     371,
#     13122,
#     86,
#     978,
#     368,
#     1151,
#     11073,
#     9904,
#     3639,
#     999,
#     77,
#     14071,
#     307,
#     11,
#     51706,
#     51744,
#     17425,
#     3881,
#     5893,
#     2884,
#     9904,
#     13,
#     51846],
#    'temperature': 0.0,
#    'avg_logprob': -0.33242393675304593,
#    'compression_ratio': 1.8359375,
#    'no_speech_prob': 3.862684479827294e-06},
#   {'id': 9,
#    'seek': 2540,
#    'start': 40.92,
#    'end': 45.480000000000004,
#    'text': ' heeft ook een polo aan met een badge boven haar borst.',
#    'tokens': [50364,
#     1346,
#     371,
#     13122,
#     86,
#     17425,
#     3881,
#     1192,
#     2884,
#     9904,
#     13,
#     50546,
#     50726,
#     12045,
#     350,
#     17158,
#     338,
#     17425,
#     5430,
#     21845,
#     46980,
#     39371,
#     13,
#     50874,
#     50986,
#     1346,
#     371,
#     13122,
#     86,
#     978,
#     368,
#     1151,
#     11073,
#     9904,
#     3639,
#     999,
#     77,
#     14071,
#     307,
#     11,
#     51136,
#     51140,
#     17425,
#     7839,
#     3881,
#     1180,
#     78,
#     9904,
#     1131,
#     3881,
#     25797,
#     748,
#     553,
#     39371,
#     14828,
#     372,
#     13,
#     51368,
#     51492,
#     1346,
#     371,
#     13122,
#     86,
#     978,
#     368,
#     1151,
#     11073,
#     9904,
#     3639,
#     999,
#     77,
#     14071,
#     307,
#     11,
#     51706,
#     51744,
#     17425,
#     3881,
#     5893,
#     2884,
#     9904,
#     13,
#     51846],
#    'temperature': 0.0,
#    'avg_logprob': -0.33242393675304593,
#    'compression_ratio': 1.8359375,
#    'no_speech_prob': 3.862684479827294e-06},
#   {'id': 10,
#    'seek': 2540,
#    'start': 47.959999999999994,
#    'end': 52.239999999999995,
#    'text': ' De vrouw die de bestelling aan het opnemen is,',
#    'tokens': [50364,
#     1346,
#     371,
#     13122,
#     86,
#     17425,
#     3881,
#     1192,
#     2884,
#     9904,
#     13,
#     50546,
#     50726,
#     12045,
#     350,
#     17158,
#     338,
#     17425,
#     5430,
#     21845,
#     46980,
#     39371,
#     13,
#     50874,
#     50986,
#     1346,
#     371,
#     13122,
#     86,
#     978,
#     368,
#     1151,
#     11073,
#     9904,
#     3639,
#     999,
#     77,
#     14071,
#     307,
#     11,
#     51136,
#     51140,
#     17425,
#     7839,
#     3881,
#     1180,
#     78,
#     9904,
#     1131,
#     3881,
#     25797,
#     748,
#     553,
#     39371,
#     14828,
#     372,
#     13,
#     51368,
#     51492,
#     1346,
#     371,
#     13122,
#     86,
#     978,
#     368,
#     1151,
#     11073,
#     9904,
#     3639,
#     999,
#     77,
#     14071,
#     307,
#     11,
#     51706,
#     51744,
#     17425,
#     3881,
#     5893,
#     2884,
#     9904,
#     13,
#     51846],
#    'temperature': 0.0,
#    'avg_logprob': -0.33242393675304593,
#    'compression_ratio': 1.8359375,
#    'no_speech_prob': 3.862684479827294e-06},
#   {'id': 11,
#    'seek': 5224,
#    'start': 52.24,
#    'end': 55.08,
#    'text': ' heeft een dotje aan.',
#    'tokens': [50364, 17425, 3881, 5893, 2884, 9904, 13, 50506],
#    'temperature': 0.0,
#    'avg_logprob': -0.5742003122965494,
#    'compression_ratio': 0.7142857142857143,
#    'no_speech_prob': 3.000126980623463e-06}],
#  'language': 'nl'}

# %% [markdown]
# # Older code ahead, above is final

# %%
modeltypes = ["tiny","base","small","medium"] # Different model types we will loop over
# Pre-create the lists where we'll store information
models = []
transcripts = []
timings = []
language = []

for modeltype in modeltypes:
    print("Currently running: " + modeltype)
    model = whisper.load_model(modeltype)
    t = time.time()
    result = model.transcribe("audio_referential_control.wav")
    elapsed = time.time() - t
    
    models.append(modeltype)
    transcripts.append(result["text"])
    timings.append(elapsed)
    language.append(result["language"])
    print("Done running: " + modeltype)
    
df = pd.DataFrame({'Modeltype': models, 'Transcripts': transcripts, 'TimeElapsed': timings, 'Language': language})
df

# %%
# Note to self: For small, a pink progress bar appeared while loading. [only first time, not second time, weird]
#   After this was finished, it stayed there for a long time. Unsure what it was doing. 
# Crashes on 'large', so possibly not supported for Dutch

# %%
df.to_csv('C:/Users/mitch/OneDrive - UGent/Documents/GitHub/stress_cyberball-mist/transcripts/transcriptModelTest1.csv')

# %%
result.segments
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26836/3197306463.py in <module>
# ----> 1 result.segments
#
# AttributeError: 'dict' object has no attribute 'segments'

# %% [markdown]
# # This is a next test; windows not relying on information in last window
# ## Might work well, since the text can be pretty random

# %%
for modeltype in modeltypes:
    model = whisper.load_model(modeltype)
    t = time.time()
    result = model.transcribe("audio_referential_control.wav", condition_on_previous_text = False)
    elapsed = time.time() - t
    
    models.append(modeltype)
    transcripts.append(result["text"])
    timings.append(elapsed)
    break
    
df = pd.DataFrame({'Modeltype': models, 'Transcripts': transcripts, 'TimeElapsed': timings})
# Out:
#   Modeltype                                        Transcripts  TimeElapsed
# 0      tiny   Op de afbilding is een afbilding van Rieken. ...     46.84961

# %%
# https://www.thepythoncode.com/article/using-speech-recognition-to-convert-speech-to-text-python
filename = "D:/Data/EEG_Study_2/Data/Raw/Audio/ppt_12_mist_speech/audio_referential_control.wav"

# initialize the recognizer
r = sr.Recognizer()

# open the file
with sr.AudioFile(filename) as source:
    # listen for the data (load audio to memory)
    audio_data = r.record(source)
    # recognize (convert from speech to text)
    text = r.recognize_google(audio_data, language="nl-BE")
    print(text)
# Out:
# Ik zie op het scherm en rekenopgaven staan die staat op het bovenste deel van het scherm aan de rest van het scherm is wit de rekenopgaven omvat een deling eerst en vooral die tussen haakjes staat 72/2 daarna en daarna 2 aftrekkingen en met 27 en -4 sterren is gelijk aan teken en een vraagteken waarde het antwoord zou moeten komen de rekenopgaven is een vrij moeilijke rekenopgave aan moeilijker dan ik verwacht had om hier te zien te krijgen
